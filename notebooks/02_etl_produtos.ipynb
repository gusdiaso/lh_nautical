# %% [markdown]
# ### Importação das bibliotecas

# %%
import pandas as pd

# %% [markdown]
# ### Carregamento dos dados

# %%
df = pd.read_csv("../data/raw/produtos_raw.csv")

# %%
df.head(10)
# Out:
#                                          name        price  code  \
# 0                 Transponder AIS Maré Magnum  R$ 33122.52     1
# 1                   Transponder Furuno Marlin  R$ 13998.15     2
# 2                Radar Furuno Pulse Leviathan   R$ 9024.19     3
# 3                   Rádio AIS Hydro Tidal Zen   R$ 3381.88     4
# 4              Piloto Automático Furuno Storm  R$ 23669.01     5
# 5                      Transponder AIS Vector  R$ 11820.21     6
# 6                               Radar AIS Zen  R$ 19518.77     7
# 7                                 GPS AIS Zen   R$ 4984.15     8
# 8                 Transponder AIS Titan Pulse   R$ 39705.5     9
# 9  Piloto Automático Simrad Titan Flux Magnum  R$ 32033.04    10
#
#          actual_category
# 0            ELETRONICOS
# 1            ELETRONICOS
# 2  E L E T R Ô N I C O S
# 3            Eletrunicos
# 4            Eletronicoz
# 5            Eletrunicos
# 6            eLeTrÔnIcOs
# 7  E L E T R Ô N I C O S
# 8            Eletronicoz
# 9            eletrônicos

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             157 non-null    str
#  1   price            157 non-null    str
#  2   code             157 non-null    int64
#  3   actual_category  157 non-null    str
# dtypes: int64(1), str(3)
# memory usage: 5.0 KB

# %% [markdown]
# ### Padronização das categorias

# %%
df["actual_category"].unique()
# Out:
# <StringArray>
# [          'ELETRONICOS', 'E L E T R Ô N I C O S',           'Eletrunicos',
#            'Eletronicoz',           'eLeTrÔnIcOs',           'eletrônicos',
#            'Eletrônicos',          'Eletroniscos',           'Eletronicos',
#            'eletronicos',           'EletrônicoS',           'ELEtRÔNICOS',
#              'PROPULSAO',             'Propulção',                  'Prop',
#             'Propulssão',             'propulsao',     'P R O P U L S Ã O',
#               'Propução',             'propulsão',             'pRoPuLsÃo',
#              'Propulçao',             'Propulsam',             'PrOpUlSãO',
#              'Ancoragem',             'AnCoRaGeM',             'Encoragem',
#             'Ancoraguem',              'Ancorajm',             'AncorageM',
#      'A N C O R A G E M',             'ANCORAGEM',             'aNcOrAgEm',
#              'Ancorajem',              'Encoragi',             'ancoragem',
#              'Ancorajen',             'AncorajeM',             'Ancoragen']
# Length: 39, dtype: str

# %%
category_map = {
  # ELETRÔNICOS
  "ELETRONICOS":      "eletrônicos",
  "E L E T R Ô N I C O S": "eletrônicos",
  "Eletrunicos":      "eletrônicos",
  "Eletronicoz":      "eletrônicos",
  "eLeTrÔnIcOs":      "eletrônicos",
  "eletrônicos":      "eletrônicos",
  "Eletrônicos":      "eletrônicos",
  "Eletroniscos":     "eletrônicos",
  "Eletronicos":      "eletrônicos",
  "eletronicos":      "eletrônicos",
  "EletrônicoS":      "eletrônicos",
  "ELEtRÔNICOS":      "eletrônicos",

  # PROPULSÃO
  "PROPULSAO":        "propulsão",
  "Propulção":        "propulsão",
  "Prop":             "propulsão",
  "Propulssão":       "propulsão",
  "propulsao":        "propulsão",
  "P R O P U L S Ã O": "propulsão",
  "Propução":         "propulsão",
  "propulsão":        "propulsão",
  "pRoPuLsÃo":        "propulsão",
  "Propulçao":        "propulsão",
  "Propulsam":        "propulsão",
  "PrOpUlSãO":        "propulsão",

  # ANCORAGEM
  "Ancoragem":        "ancoragem",
  "AnCoRaGeM":        "ancoragem",
  "Encoragem":        "ancoragem",
  "Ancoraguem":       "ancoragem",
  "Ancorajm":         "ancoragem",
  "AncorageM":        "ancoragem",
  "A N C O R A G E M": "ancoragem",
  "ANCORAGEM":        "ancoragem",
  "aNcOrAgEm":        "ancoragem",
  "Ancorajem":        "ancoragem",
  "Encoragi":         "ancoragem",
  "ancoragem":        "ancoragem",
  "Ancorajen":        "ancoragem",
  "AncorajeM":        "ancoragem",
  "Ancoragen":        "ancoragem",
}

# %%
df["actual_category"] = df["actual_category"].map(category_map)
df["actual_category"].unique()
# Out:
# <StringArray>
# ['eletrônicos', 'propulsão', 'ancoragem']
# Length: 3, dtype: str

# %%
df.sample(10)
# Out:
#                                                 name         price  code  \
# 87   Motor de Popa Torqeedo Zenith Peak Thrust 212HP   R$ 43423.88    84
# 47                           Rádio Simrad Tidal Aqua    R$ 6122.96    47
# 23                      GPS AIS Orca Marlin Velocity   R$ 23232.18    24
# 18                    Sonda Lowrance Tidal Storm Vox   R$ 16432.35    19
# 154                Âncora Delta Force Barracuda Mako    R$ 4785.56   148
# 62                 Motor Diesel Yanmar Velocity 37HP  R$ 102221.97    62
# 21                      Transponder Furuno Force Ion   R$ 39452.86    22
# 86              Motor Diesel Yanmar Dash Nitro 184HP  R$ 134803.88    83
# 45                                GPS Furuno Current    R$ 9903.71    45
# 1                          Transponder Furuno Marlin   R$ 13998.15     2
#
#     actual_category
# 87        propulsão
# 47      eletrônicos
# 23      eletrônicos
# 18      eletrônicos
# 154       ancoragem
# 62        propulsão
# 21      eletrônicos
# 86        propulsão
# 45      eletrônicos
# 1       eletrônicos

# %% [markdown]
# ### Convertendo preço para o tipo numerico

# %%
df['price'] = df['price'].str.replace('R$', '').str.strip()
df['price'] = pd.to_numeric(df['price'])

# %%
df.sample(10)
# Out:
#                                              name      price  code  \
# 12                             Radar Simrad Boost    7747.10    13
# 26                   GPS Garmin Vortex Maré Drift   16511.45    27
# 134                          Corrente Delta Boost    3266.21   129
# 76   Motor de Popa Torqeedo Core Hydra Flux 162HP  143159.93    73
# 28                              Rádio Simrad Orca   36510.34    29
# 119    Cabo de Nylon Delta Velocity Oceanic Abyss    2575.52   116
# 115                       Corrente Danforth Tidal    2180.95   112
# 23                   GPS AIS Orca Marlin Velocity   23232.18    24
# 144           Boia de Arqueamento Danforth Torque    1424.88   139
# 29                          Transponder AIS Boost   32247.87    30
#
#     actual_category
# 12      eletrônicos
# 26      eletrônicos
# 134       ancoragem
# 76        propulsão
# 28      eletrônicos
# 119       ancoragem
# 115       ancoragem
# 23      eletrônicos
# 144       ancoragem
# 29      eletrônicos

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             157 non-null    str
#  1   price            157 non-null    float64
#  2   code             157 non-null    int64
#  3   actual_category  157 non-null    str
# dtypes: float64(1), int64(1), str(2)
# memory usage: 5.0 KB

# %% [markdown]
# ### Verificar duplicatas

# %%
df.duplicated().sum()
# Out:
# np.int64(7)

# %%
df[df.duplicated()]
# Out:
#                                        name      price  code actual_category
# 37             GPS Lowrance Evo Storm Drift    6067.71    37     eletrônicos
# 63        Motor Diesel Yanmar Velocity 37HP  102221.97    62       propulsão
# 64        Motor Diesel Yanmar Velocity 37HP  102221.97    62       propulsão
# 65        Motor Diesel Yanmar Velocity 37HP  102221.97    62       propulsão
# 132  Cabo de Nylon Delta Velocity Core Mako    1549.35   127       ancoragem
# 150         Boia de Arqueamento Delta Nexus    4349.86   145       ancoragem
# 151         Boia de Arqueamento Delta Nexus    4349.86   145       ancoragem

# %%
df[df["code"].isin([37, 62, 127, 145])].sort_values(by="code")
# Out:
#                                        name      price  code actual_category
# 36             GPS Lowrance Evo Storm Drift    6067.71    37     eletrônicos
# 37             GPS Lowrance Evo Storm Drift    6067.71    37     eletrônicos
# 62        Motor Diesel Yanmar Velocity 37HP  102221.97    62       propulsão
# 63        Motor Diesel Yanmar Velocity 37HP  102221.97    62       propulsão
# 64        Motor Diesel Yanmar Velocity 37HP  102221.97    62       propulsão
# 65        Motor Diesel Yanmar Velocity 37HP  102221.97    62       propulsão
# 131  Cabo de Nylon Delta Velocity Core Mako    1549.35   127       ancoragem
# 132  Cabo de Nylon Delta Velocity Core Mako    1549.35   127       ancoragem
# 124         Boia de Arqueamento Delta Nexus    4349.86   145       ancoragem
# 150         Boia de Arqueamento Delta Nexus    4349.86   145       ancoragem
# 151         Boia de Arqueamento Delta Nexus    4349.86   145       ancoragem

# %%
df = df.drop_duplicates(subset='code', keep='first')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df["code"].isin([37, 62, 127, 145])].sort_values(by="code")
# Out:
#                                        name      price  code actual_category
# 36             GPS Lowrance Evo Storm Drift    6067.71    37     eletrônicos
# 62        Motor Diesel Yanmar Velocity 37HP  102221.97    62       propulsão
# 131  Cabo de Nylon Delta Velocity Core Mako    1549.35   127       ancoragem
# 124         Boia de Arqueamento Delta Nexus    4349.86   145       ancoragem

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 150 entries, 0 to 156
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             150 non-null    str
#  1   price            150 non-null    float64
#  2   code             150 non-null    int64
#  3   actual_category  150 non-null    str
# dtypes: float64(1), int64(1), str(2)
# memory usage: 5.9 KB

# %%
df.sample(20)
# Out:
#                                              name      price  code  \
# 103       Motor Elétrico Honda Vector Abyss 220HP  104600.24   100
# 116                       Âncora Delta Mako Ultra    4394.96   113
# 135    Boia de Arqueamento Delta Zen Boost Vortex    4144.09   130
# 118    Cabo de Nylon Delta Force Magnum Leviathan     830.59   115
# 133        Boia de Arqueamento Bruce Marlin Hydra    4650.72   128
# 70                Motor de Popa Yamaha Mako 108HP   85789.05    67
# 55          Motor Diesel Volvo Flow Oceanic 259HP  109987.20    55
# 89       Motor Diesel Volvo Helix Evo Force 144HP   93523.13    86
# 96               Motor Elétrico Yamaha Flow 204HP  100477.01    93
# 107          Cabo de Nylon Delta Zen Vortex Storm    3713.02   104
# 62              Motor Diesel Yanmar Velocity 37HP  102221.97    62
# 108                  Cabo de Nylon Danforth Prime     309.54   105
# 122                             Âncora Bruce Aqua    3255.82   119
# 38                                Rádio AIS Force   26461.14    38
# 13                         Rádio Furuno Zen Swift   35811.08    14
# 129                Cabo de Nylon Danforth Kinetic    3402.07   125
# 3                       Rádio AIS Hydro Tidal Zen    3381.88     4
# 59   Motor Diesel Yanmar Hydro Magnum Boost 267HP   87166.14    59
# 97               Motor de Popa Volvo Magnum 276HP   40750.84    94
# 43                            Sonda AIS Barracuda   35096.86    43
#
#     actual_category
# 103       propulsão
# 116       ancoragem
# 135       ancoragem
# 118       ancoragem
# 133       ancoragem
# 70        propulsão
# 55        propulsão
# 89        propulsão
# 96        propulsão
# 107       ancoragem
# 62        propulsão
# 108       ancoragem
# 122       ancoragem
# 38      eletrônicos
# 13      eletrônicos
# 129       ancoragem
# 3       eletrônicos
# 59        propulsão
# 97        propulsão
# 43      eletrônicos

# %%
df.to_csv('../data/processed/produtos_processed.csv', index=False)
